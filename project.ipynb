# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ## Step 1 Data loading and exploration

# %%
#### Importing dependencies
import pandas as pd

# postgresql
from sqlalchemy import create_engine
import psycopg2

# %%
print(pd.__version__)
# Out:
# 3.0.1

# %%
df = pd.read_csv('Walmart.csv', encoding_errors='ignore')

# %%
df.head()
# Out:
#    invoice_id   branch         city                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin   total
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48  522.83
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48   76.40
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33  324.31
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33  465.76
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48  604.17

# %%
df.shape
# Out:
# (9969, 12)

# %%
df.describe()
# Out:
#          invoice_id   unit_price     quantity       rating  profit_margin  \
# count   9969.000000  9969.000000  9969.000000  9969.000000    9969.000000
# mean    5010.116561    50.622142     2.355602     5.828839       0.393744
# std     2886.217349    21.203766     1.605455     1.763723       0.090659
# min        1.000000    10.080000     1.000000     3.000000       0.180000
# 25%     2524.000000    32.000000     1.000000     4.000000       0.330000
# 50%     5016.000000    51.000000     2.000000     6.000000       0.330000
# 75%     7508.000000    69.000000     3.000000     7.000000       0.480000
# max    10000.000000    99.960000    10.000000    10.000000       0.570000
#
#              total
# count  9969.000000
# mean    121.348819
# std     112.678040
# min      10.170000
# 25%      54.000000
# 50%      88.000000
# 75%     156.000000
# max     993.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9969 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      9969 non-null   int64
#  1   branch          9969 non-null   str
#  2   city            9969 non-null   str
#  3   category        9969 non-null   str
#  4   unit_price      9969 non-null   float64
#  5   quantity        9969 non-null   float64
#  6   date            9969 non-null   str
#  7   time            9969 non-null   str
#  8   payment_method  9969 non-null   str
#  9   rating          9969 non-null   float64
#  10  profit_margin   9969 non-null   float64
#  11  total           9969 non-null   float64
# dtypes: float64(5), int64(1), str(6)
# memory usage: 1012.5 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# invoice_id        0
# branch            0
# city              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# total             0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (9969, 12)

# %%
# dropping all rows with missing records
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# invoice_id        0
# branch            0
# city              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# total             0
# dtype: int64

# %%
df.shape
# Out:
# (9969, 12)

# %%
df.dtypes
# Out:
# invoice_id          int64
# branch                str
# city                  str
# category              str
# unit_price        float64
# quantity          float64
# date                  str
# time                  str
# payment_method        str
# rating            float64
# profit_margin     float64
# total             float64
# dtype: object

# %%
df['unit_price']= df['unit_price'].str.replace('$', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df['unit_price']= df['unit_price'].str.replace('$', '').astype(float)
#
# File d:\Walmart\my_venv1\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6199 if (
#    6200     name not in self._internal_names_set
#    6201     and name not in self._metadata
#    6202     and name not in self._accessors
#    6203     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204 ):
#    6205     return self[name]
# -> 6206 return object.__getattribute__(self, name)
#
# File d:\Walmart\my_venv1\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# ...

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9969 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      9969 non-null   int64
#  1   branch          9969 non-null   str
#  2   city            9969 non-null   str
#  3   category        9969 non-null   str
#  4   unit_price      9969 non-null   float64
#  5   quantity        9969 non-null   float64
#  6   date            9969 non-null   str
#  7   time            9969 non-null   str
#  8   payment_method  9969 non-null   str
#  9   rating          9969 non-null   float64
#  10  profit_margin   9969 non-null   float64
#  11  total           9969 non-null   float64
# dtypes: float64(5), int64(1), str(6)
# memory usage: 1012.5 KB

# %%
df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin', 'total'],
#       dtype='str')

# %%
df['total'] = df['unit_price'] * df['quantity']

# %%
df.head()
# Out:
#    invoice_id   branch         city                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin   total
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48  522.83
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48   76.40
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33  324.31
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33  465.76
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48  604.17

# %%
df.rename(columns={
    "Branch": "branch",
    "City": "city"
}, inplace=True)

# %%
# OR
#df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin', 'total'],
#       dtype='str')

# %%
df.to_csv('walmart_cleaned_data.csv', index=False)

# %%
df.shape
# Out:
# (9969, 12)

# %%
# Postgresql connection
#postgresql+pyscopg2://user:password@localhost:5432/db_name
engine_postgres = create_engine('postgresql+psycopg2://postgres:anisha@localhost:5432/walmart_db')

try: 
    engine_postgres
    print('Connection successfull to postgres')
except:
    print('Unable to connect')
# Out:
# Connection successfull to postgres

# %%
df.to_sql(name='walmart', con=engine_postgres, if_exists='append', index=False)
# Out:
# 969
